# %% [markdown]
# # Notebook Title: [Insert Title]
#
# #### Overview
# This notebook is designed to [briefly describe the primary purpose of the notebook, e.g., "perform data ingestion, transformation, and analysis on product data"].
#
# ---
#
# #### Key Functionalities
# - **Data Ingestion**: [Describe data sources, e.g., "Load data from ADLS and external sources"].
# - **Data Transformation**: [Explain transformations, e.g., "Clean, filter, and aggregate raw data"].
# - **Data Analysis**: [Describe analysis, e.g., "Perform statistical analysis and generate visualizations"].
# - **Output**: [Specify outputs, e.g., "Save results to Delta Lake tables and generate reports"].
#
# ---
#
# #### Prerequisites
# - **Libraries**: [List required libraries, e.g., "pandas, PySpark, matplotlib"].
# - **Data Sources**: [List data sources, e.g., "ADLS, SQL Database"].
# - **Permissions**: [Specify access requirements, e.g., "Read/write access to Lakehouse_Bronze"].
#
# ---
#
# #### Usage Instructions
# 1. **Set Up**: Ensure all dependencies are installed using [e.g., "Library Management in Fabric"].
# 2. **Run Cells**: Execute cells sequentially to [e.g., "ingest, transform, and analyze data"].
# 3. **Modify Parameters**: Adjust parameters in the [e.g., "configuration cell"] as needed.
# 4. **Save Outputs**: Check the output paths for [e.g., "processed data and reports"].
#
# ---
#
# #### Notes
# - **Assumptions**: [List assumptions, e.g., "Data is stored in Delta Lake format"].
# - **Limitations**: [Highlight limitations, e.g., "Designed for datasets under 1TB"].
# - **Version**: [Specify version, e.g., "v1.0.0"].
#
# ---
#
# #### Contact
# For questions or issues, contact [Your Name] at [Your Email].

# %% [markdown]
# ## Input

# %%
# put here your logic to read data

# %% [markdown]
# ## Transform

# %%
# here you will apply all your transformation logic

# %% [markdown]
# ## Output

# %%
# here you will apply all your logic to save the dataframes to your target location
